# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import joblib
import csv
import optuna

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import (
    classification_report, f1_score, accuracy_score,
    precision_score, recall_score, confusion_matrix
)
from sklearn.model_selection import StratifiedShuffleSplit
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import SGD

warnings.filterwarnings("ignore", category=UserWarning)

# === Ruta base ===
base_path = os.getcwd()
csv_path = os.path.join(base_path, "df_train.csv")

# === 1. Cargar datos ===
df = pd.read_csv(csv_path)
df['time'] = pd.to_datetime(df['time'])
df['year'] = df['time'].dt.year
df['month'] = df['time'].dt.month
df['week'] = df['time'].dt.isocalendar().week
df['hour'] = df['time'].dt.hour
df['weekday'] = df['time'].dt.weekday

# === 2. Filtrar y preparar ===
df = df[(df['signal'] == 1) & (df['label'].notna())].copy()
df['label'] = df['label'].astype(int)

features_cols = [
    'close', 'sma_200_vs_100', 'sma_50_vs_25', 'rsi_14', 'acceleration_12',
    'macd', 'stoch_k', 'momentum_12', 'bb_middle', 'bb_upper', 'bb_lower',
    'weighted_close', 'poc_12', 'high_channel_20', 'low_channel_20',
    'abs_diff_mrb_vs_close', 'last_signal_price_1', 'last_signal_price_2',
    'last_signal_price_3', 'last_signal_price_4', 'last_signal_price_5',
    'hour', 'weekday'
]

# === 3. Walk-forward semanal ===
df['year_week'] = df['time'].dt.strftime('%Y-%U')
unique_periods = sorted(df['year_week'].unique())
min_train_weeks = 12

scores, accs, precs, recalls, dropouts, lrs, moms = [], [], [], [], [], [], []
final_model = None

results_path = os.path.join(base_path, "results_walkforward_weekly_keras_optuna.csv")

with open(results_path, "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerow(["Periodo", "F1_Score", "Accuracy", "Precision", "Recall", "Dropout", "LR", "Momentum"])

    for i in range(min_train_weeks, len(unique_periods) - 1):
        train_periods = unique_periods[i - min_train_weeks:i]
        test_period = unique_periods[i]

        df_train = df[df['year_week'].isin(train_periods)].copy()
        df_test = df[df['year_week'] == test_period].copy()

        if df_train.empty or df_test.empty:
            continue

        X_train = df_train[features_cols].fillna(0).values
        y_train = df_train['label'].values
        X_test = df_test[features_cols].fillna(0).values
        y_test = df_test['label'].values

        scaler = MinMaxScaler()
        X_train = scaler.fit_transform(X_train)
        X_test = scaler.transform(X_test)

        def create_model(trial):
            model = Sequential()
            n_units1 = trial.suggest_int('n_units1', 32, 96)
            n_units2 = trial.suggest_int('n_units2', 16, 48)
            dropout_rate = trial.suggest_float('dropout_rate', 0.1, 0.5)
            learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-1, log=True)
            momentum = trial.suggest_float('momentum', 0.0, 0.9)

            model.add(Dense(n_units1, activation='tanh', input_shape=(X_train.shape[1],)))
            model.add(Dropout(dropout_rate))
            model.add(Dense(n_units2, activation='tanh'))
            model.add(Dropout(dropout_rate))
            model.add(Dense(1, activation='sigmoid'))

            opt = SGD(learning_rate=learning_rate, momentum=momentum)
            model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
            return model

        def objective(trial):
            model = create_model(trial)
            es = EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)
            model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32, callbacks=[es], verbose=0)
            y_pred = model.predict(X_test).flatten()
            y_pred = (y_pred > 0.5).astype(int)
            return f1_score(y_test, y_pred, average='weighted')

        study = optuna.create_study(direction='maximize')
        study.optimize(objective, n_trials=20, timeout=600)

        best_trial = study.best_trial
        best_model = create_model(best_trial)
        best_model.fit(X_train, y_train, validation_split=0.2, epochs=100, batch_size=32, callbacks=[EarlyStopping(monitor='val_loss', patience=8, restore_best_weights=True)], verbose=0)

        y_pred_probs = best_model.predict(X_test).flatten()
        y_pred = (y_pred_probs > 0.5).astype(int)

        f1 = f1_score(y_test, y_pred, average='weighted')
        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)

        scores.append(f1)
        accs.append(acc)
        precs.append(prec)
        recalls.append(rec)
        dropouts.append(best_trial.params['dropout_rate'])
        lrs.append(best_trial.params['learning_rate'])
        moms.append(best_trial.params['momentum'])

        print("\nMatriz de confusión:")
        print(confusion_matrix(y_test, y_pred))

        writer.writerow([test_period, f1, acc, prec, rec, best_trial.params['dropout_rate'], best_trial.params['learning_rate'], best_trial.params['momentum']])
        final_model = best_model

# === Guardar el modelo final ===
if final_model:
    final_model.save(os.path.join(base_path, "best_model_walkforward_keras_optuna.h5"))
    print("\u2705 Modelo Keras-Optuna guardado como best_model_walkforward_keras_optuna.h5")

# === Visualización ===
print("\n\ud83d\udcca Métricas promedio generales:")
print(f"\ud83d\udd39 F1 Score promedio:      {np.mean(scores):.4f}")
print(f"\ud83d\udd39 Accuracy promedio:      {np.mean(accs):.4f}")
print(f"\ud83d\udd39 Precision promedio:     {np.mean(precs):.4f}")
print(f"\ud83d\udd39 Recall promedio:        {np.mean(recalls):.4f}")

plt.figure(figsize=(10, 5))
plt.plot(scores, marker='o', label='F1 Score')
plt.axhline(np.mean(scores), color='red', linestyle='--', label='Promedio F1')
plt.title('Walk-Forward Weekly - F1 Score (Keras + Optuna)')
plt.xlabel('Fold')
plt.ylabel('F1 Score')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [I 2025-05-25 11:07:59,782] A new study created in memory with name: no-name-4eb5d252-1109-4758-a269-a895f0b554f0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [I 2025-05-25 11:08:02,734] Trial 0 finished with value: 0.6124401913875598 and parameters: {'n_units1': 48, 'n_units2': 42, 'dropout_rate': 0.3382374548935926, 'learning_rate': 0.01983010821733412, 'momentum': 0.5076889063100609}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# [I 2025-05-25 11:08:12,640] Trial 1 finished with value: 0.6124401913875598 and parameters: {'n_units1': 32, 'n_units2': 17, 'dropout_rate': 0.12885343774135516, 'learning_rate': 0.0009451275309729445, 'momentum': 0.6319238156212418}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# [I 2025-05-25 11:08:27,529] Trial 2 finished with value: 0.6124401913875598 and parameters: {'n_units1': 92, 'n_units2': 27, 'dropout_rate': 0.13718967913497113, 'learning_rate': 0.00020235772499900364, 'momentum': 0.5612439505484256}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# [I 2025-05-25 11:08:35,843] Trial 3 finished with value: 0.6124401913875598 and parameters: {'n_units1': 47, 'n_units2': 16, 'dropout_rate': 0.31285075522555716, 'learning_rate': 0.002286693380940082, 'momentum': 0.7968284059574382}. Best is trial 0 with value: 0.6124401913875598.
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026CD65537E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [I 2025-05-25 11:08:38,632] Trial 4 finished with value: 0.6124401913875598 and parameters: {'n_units1': 88, 'n_units2': 33, 'dropout_rate': 0.20751905143602573, 'learning_rate': 0.04072865567595763, 'momentum': 0.565756665442626}. Best is trial 0 with value: 0.6124401913875598.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026CD675D9E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:08:56,264] Trial 5 finished with value: 0.6124401913875598 and parameters: {'n_units1': 79, 'n_units2': 36, 'dropout_rate': 0.18296312950801377, 'learning_rate': 0.0008785401307898734, 'momentum': 0.013991014466867535}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# [I 2025-05-25 11:09:12,917] Trial 6 finished with value: 0.6124401913875598 and parameters: {'n_units1': 79, 'n_units2': 28, 'dropout_rate': 0.2752564146514003, 'learning_rate': 0.0002706140556230014, 'momentum': 0.361033862200743}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:09:25,119] Trial 7 finished with value: 0.6124401913875598 and parameters: {'n_units1': 39, 'n_units2': 21, 'dropout_rate': 0.17644472664263705, 'learning_rate': 0.00900118706790267, 'momentum': 0.423217027044852}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# [I 2025-05-25 11:09:40,114] Trial 8 finished with value: 0.6124401913875598 and parameters: {'n_units1': 45, 'n_units2': 21, 'dropout_rate': 0.426565785386252, 'learning_rate': 0.004004792112554845, 'momentum': 0.6486661370996918}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:09:56,841] Trial 9 finished with value: 0.6124401913875598 and parameters: {'n_units1': 83, 'n_units2': 21, 'dropout_rate': 0.248510117796525, 'learning_rate': 0.000979421186478236, 'momentum': 0.15011595484296023}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [I 2025-05-25 11:10:00,382] Trial 10 finished with value: 0.6124401913875598 and parameters: {'n_units1': 61, 'n_units2': 47, 'dropout_rate': 0.3867444304982991, 'learning_rate': 0.0728369207126501, 'momentum': 0.8981819764434458}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:10:08,756] Trial 11 finished with value: 0.6124401913875598 and parameters: {'n_units1': 33, 'n_units2': 43, 'dropout_rate': 0.35275040673906943, 'learning_rate': 0.014597028162090119, 'momentum': 0.32116958437511445}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# [I 2025-05-25 11:10:13,825] Trial 12 finished with value: 0.6124401913875598 and parameters: {'n_units1': 56, 'n_units2': 39, 'dropout_rate': 0.48499256467298735, 'learning_rate': 0.02077366379724368, 'momentum': 0.6943164802572429}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [I 2025-05-25 11:10:31,065] Trial 13 finished with value: 0.6124401913875598 and parameters: {'n_units1': 32, 'n_units2': 48, 'dropout_rate': 0.1124300102833114, 'learning_rate': 0.004114527258277205, 'momentum': 0.4928523306592073}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# [I 2025-05-25 11:10:48,430] Trial 14 finished with value: 0.6124401913875598 and parameters: {'n_units1': 52, 'n_units2': 41, 'dropout_rate': 0.3305570058375241, 'learning_rate': 0.0006193635334560633, 'momentum': 0.7158427262645182}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:11:05,848] Trial 15 finished with value: 0.6124401913875598 and parameters: {'n_units1': 68, 'n_units2': 29, 'dropout_rate': 0.23631043383759073, 'learning_rate': 0.00010147684590454559, 'momentum': 0.23658674672854116}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# [I 2025-05-25 11:11:22,806] Trial 16 finished with value: 0.6124401913875598 and parameters: {'n_units1': 43, 'n_units2': 35, 'dropout_rate': 0.4163117149868696, 'learning_rate': 0.0021803552565009842, 'momentum': 0.5371969883753441}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# [I 2025-05-25 11:11:27,788] Trial 17 finished with value: 0.6124401913875598 and parameters: {'n_units1': 67, 'n_units2': 16, 'dropout_rate': 0.4768679855535398, 'learning_rate': 0.008048784560749214, 'momentum': 0.8035499811361544}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:11:32,256] Trial 18 finished with value: 0.6124401913875598 and parameters: {'n_units1': 40, 'n_units2': 45, 'dropout_rate': 0.2783172294829447, 'learning_rate': 0.08371796546633778, 'momentum': 0.4269907959055659}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# [I 2025-05-25 11:11:36,282] Trial 19 finished with value: 0.6124401913875598 and parameters: {'n_units1': 56, 'n_units2': 39, 'dropout_rate': 0.36213161658855375, 'learning_rate': 0.021511065102284416, 'momentum': 0.6144299579945423}. Best is trial 0 with value: 0.6124401913875598.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:11:40,855] A new study created in memory with name: no-name-e6e16094-bd74-4778-a489-6b64165003c9
# Matriz de confusión:
# [[0 3]
#  [0 8]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# [I 2025-05-25 11:11:45,193] Trial 0 finished with value: 1.0 and parameters: {'n_units1': 92, 'n_units2': 46, 'dropout_rate': 0.30935161934976413, 'learning_rate': 0.009466082816417193, 'momentum': 0.09691507917337248}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# [I 2025-05-25 11:11:49,420] Trial 1 finished with value: 1.0 and parameters: {'n_units1': 94, 'n_units2': 20, 'dropout_rate': 0.3494461658692838, 'learning_rate': 0.007675351334112623, 'momentum': 0.04702619258354364}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:11:52,183] Trial 2 finished with value: 1.0 and parameters: {'n_units1': 49, 'n_units2': 16, 'dropout_rate': 0.49916350209763616, 'learning_rate': 0.027958615044868147, 'momentum': 0.6217125180401859}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:11:55,121] Trial 3 finished with value: 1.0 and parameters: {'n_units1': 48, 'n_units2': 28, 'dropout_rate': 0.14694892004175714, 'learning_rate': 0.02543361793843067, 'momentum': 0.22849111319231372}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# [I 2025-05-25 11:12:11,027] Trial 4 finished with value: 1.0 and parameters: {'n_units1': 62, 'n_units2': 38, 'dropout_rate': 0.3054341425932702, 'learning_rate': 0.0004131170468745803, 'momentum': 0.26357056148718605}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:12:15,925] Trial 5 finished with value: 1.0 and parameters: {'n_units1': 85, 'n_units2': 44, 'dropout_rate': 0.2916415075412209, 'learning_rate': 0.002719133085759863, 'momentum': 0.5564218040981571}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# [I 2025-05-25 11:12:23,968] Trial 6 finished with value: 1.0 and parameters: {'n_units1': 52, 'n_units2': 39, 'dropout_rate': 0.3224560869799028, 'learning_rate': 0.001162489459453828, 'momentum': 0.6078463830283414}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:12:31,826] Trial 7 finished with value: 1.0 and parameters: {'n_units1': 61, 'n_units2': 26, 'dropout_rate': 0.4066698866255336, 'learning_rate': 0.0014170895707334857, 'momentum': 0.5538745368564856}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:12:34,836] Trial 8 finished with value: 1.0 and parameters: {'n_units1': 76, 'n_units2': 17, 'dropout_rate': 0.18113180691589137, 'learning_rate': 0.011376120674507969, 'momentum': 0.7708813447012196}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [I 2025-05-25 11:12:39,059] Trial 9 finished with value: 1.0 and parameters: {'n_units1': 79, 'n_units2': 27, 'dropout_rate': 0.2438882817071217, 'learning_rate': 0.00796095995889587, 'momentum': 0.21494176926723796}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [I 2025-05-25 11:12:41,957] Trial 10 finished with value: 1.0 and parameters: {'n_units1': 32, 'n_units2': 48, 'dropout_rate': 0.41346672896561315, 'learning_rate': 0.06579597470532167, 'momentum': 0.04045156201345272}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:12:47,085] Trial 11 finished with value: 1.0 and parameters: {'n_units1': 94, 'n_units2': 35, 'dropout_rate': 0.37705524452021866, 'learning_rate': 0.006421388647877867, 'momentum': 0.02321118309632475}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# [I 2025-05-25 11:13:04,042] Trial 12 finished with value: 1.0 and parameters: {'n_units1': 96, 'n_units2': 22, 'dropout_rate': 0.23081233279895447, 'learning_rate': 0.00032689718621671944, 'momentum': 0.3531702970196524}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:13:20,025] Trial 13 finished with value: 1.0 and parameters: {'n_units1': 86, 'n_units2': 33, 'dropout_rate': 0.361114372727381, 'learning_rate': 0.00012512739226146815, 'momentum': 0.12797193991292005}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# [I 2025-05-25 11:13:22,790] Trial 14 finished with value: 1.0 and parameters: {'n_units1': 72, 'n_units2': 21, 'dropout_rate': 0.4688264131138907, 'learning_rate': 0.08738114806929724, 'momentum': 0.3865335684139557}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step
# [I 2025-05-25 11:13:28,670] Trial 15 finished with value: 1.0 and parameters: {'n_units1': 87, 'n_units2': 42, 'dropout_rate': 0.25271333923030254, 'learning_rate': 0.0034318071318690797, 'momentum': 0.12716444015027906}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# [I 2025-05-25 11:13:32,397] Trial 16 finished with value: 1.0 and parameters: {'n_units1': 71, 'n_units2': 48, 'dropout_rate': 0.34395222705097134, 'learning_rate': 0.02057463614743356, 'momentum': 0.00809305087243295}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# [I 2025-05-25 11:13:35,856] Trial 17 finished with value: 1.0 and parameters: {'n_units1': 91, 'n_units2': 29, 'dropout_rate': 0.4246975066495876, 'learning_rate': 0.0032416634828328784, 'momentum': 0.8278986105873398}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# [I 2025-05-25 11:13:39,792] Trial 18 finished with value: 1.0 and parameters: {'n_units1': 80, 'n_units2': 22, 'dropout_rate': 0.2732917724357999, 'learning_rate': 0.013137424187997902, 'momentum': 0.1297052704687325}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:13:42,433] Trial 19 finished with value: 1.0 and parameters: {'n_units1': 96, 'n_units2': 32, 'dropout_rate': 0.20519302604289935, 'learning_rate': 0.0447934929114904, 'momentum': 0.32060462389521566}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:13:46,026] A new study created in memory with name: no-name-fda9b9e6-969b-4115-9e63-860109d763b6
# Matriz de confusión:
# [[18]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:13:52,272] Trial 0 finished with value: 0.6805555555555556 and parameters: {'n_units1': 36, 'n_units2': 20, 'dropout_rate': 0.4086957107929653, 'learning_rate': 0.00540742201959154, 'momentum': 0.19362892935390616}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [I 2025-05-25 11:14:09,215] Trial 1 finished with value: 0.6805555555555556 and parameters: {'n_units1': 88, 'n_units2': 34, 'dropout_rate': 0.10413083812249738, 'learning_rate': 0.0003278161224963704, 'momentum': 0.10078019685903804}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:14:26,134] Trial 2 finished with value: 0.6805555555555556 and parameters: {'n_units1': 42, 'n_units2': 24, 'dropout_rate': 0.1612218399505937, 'learning_rate': 0.0002597941260246374, 'momentum': 0.5727906975350087}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# [I 2025-05-25 11:14:28,995] Trial 3 finished with value: 0.6805555555555556 and parameters: {'n_units1': 85, 'n_units2': 32, 'dropout_rate': 0.4741708290441574, 'learning_rate': 0.05640167336179065, 'momentum': 0.2328133904942166}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:14:33,365] Trial 4 finished with value: 0.6805555555555556 and parameters: {'n_units1': 51, 'n_units2': 17, 'dropout_rate': 0.20248715923903401, 'learning_rate': 0.017961483739092038, 'momentum': 0.11994007901188272}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [I 2025-05-25 11:14:37,706] Trial 5 finished with value: 0.6805555555555556 and parameters: {'n_units1': 82, 'n_units2': 24, 'dropout_rate': 0.49532800917717523, 'learning_rate': 0.006678779545349513, 'momentum': 0.7031868514253623}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:14:42,012] Trial 6 finished with value: 0.6805555555555556 and parameters: {'n_units1': 32, 'n_units2': 18, 'dropout_rate': 0.40483480589988863, 'learning_rate': 0.043893632889984165, 'momentum': 0.8370510922394089}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# [I 2025-05-25 11:14:58,366] Trial 7 finished with value: 0.6805555555555556 and parameters: {'n_units1': 62, 'n_units2': 29, 'dropout_rate': 0.3160387822285722, 'learning_rate': 0.0007746917974481565, 'momentum': 0.46822733348274365}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# [I 2025-05-25 11:15:02,423] Trial 8 finished with value: 0.6805555555555556 and parameters: {'n_units1': 46, 'n_units2': 35, 'dropout_rate': 0.19706366612573475, 'learning_rate': 0.005294819243999587, 'momentum': 0.6530336554248958}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:15:07,371] Trial 9 finished with value: 0.6805555555555556 and parameters: {'n_units1': 73, 'n_units2': 46, 'dropout_rate': 0.1198427467756146, 'learning_rate': 0.0018801281810935818, 'momentum': 0.6530360197614378}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [I 2025-05-25 11:15:18,994] Trial 10 finished with value: 0.6805555555555556 and parameters: {'n_units1': 60, 'n_units2': 48, 'dropout_rate': 0.3379075970458297, 'learning_rate': 0.0015074276098318354, 'momentum': 0.30890937116356854}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:15:35,436] Trial 11 finished with value: 0.6805555555555556 and parameters: {'n_units1': 95, 'n_units2': 39, 'dropout_rate': 0.26531629062092565, 'learning_rate': 0.00010161806443432706, 'momentum': 0.05164986338242405}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [I 2025-05-25 11:15:52,185] Trial 12 finished with value: 0.6805555555555556 and parameters: {'n_units1': 72, 'n_units2': 40, 'dropout_rate': 0.39911801769651256, 'learning_rate': 0.0006457787200489027, 'momentum': 0.268512532328553}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:15:56,324] Trial 13 finished with value: 0.6805555555555556 and parameters: {'n_units1': 95, 'n_units2': 24, 'dropout_rate': 0.4052496778562887, 'learning_rate': 0.011878847308213682, 'momentum': 0.020852537183496223}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [I 2025-05-25 11:16:13,188] Trial 14 finished with value: 0.6805555555555556 and parameters: {'n_units1': 32, 'n_units2': 28, 'dropout_rate': 0.25964543200538737, 'learning_rate': 0.00030942355351388953, 'momentum': 0.1741591492905276}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:16:22,427] Trial 15 finished with value: 0.6805555555555556 and parameters: {'n_units1': 55, 'n_units2': 36, 'dropout_rate': 0.10434943249631193, 'learning_rate': 0.0027213366825022504, 'momentum': 0.3561630252698772}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# [I 2025-05-25 11:16:39,336] Trial 16 finished with value: 0.6805555555555556 and parameters: {'n_units1': 73, 'n_units2': 20, 'dropout_rate': 0.36237500368014036, 'learning_rate': 0.0001313159761192115, 'momentum': 0.419225257774561}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:16:56,748] Trial 17 finished with value: 0.6805555555555556 and parameters: {'n_units1': 82, 'n_units2': 42, 'dropout_rate': 0.4454153931792103, 'learning_rate': 0.0006646560118303047, 'momentum': 0.1355308900068448}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# [I 2025-05-25 11:17:00,522] Trial 18 finished with value: 0.6805555555555556 and parameters: {'n_units1': 39, 'n_units2': 30, 'dropout_rate': 0.2720268772263982, 'learning_rate': 0.02436819511995397, 'momentum': 0.00463340187105582}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:17:05,518] Trial 19 finished with value: 0.6805555555555556 and parameters: {'n_units1': 66, 'n_units2': 35, 'dropout_rate': 0.21851576981955012, 'learning_rate': 0.005850618616473965, 'momentum': 0.20344551894090968}. Best is trial 0 with value: 0.6805555555555556.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# [I 2025-05-25 11:17:14,120] A new study created in memory with name: no-name-1e1faaa5-bbaa-422e-a940-9bcf6eb2e1e5
# Matriz de confusión:
# [[ 0  4]
#  [ 0 14]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# [I 2025-05-25 11:17:25,266] Trial 0 finished with value: 0.5841784989858012 and parameters: {'n_units1': 47, 'n_units2': 44, 'dropout_rate': 0.3805078407216348, 'learning_rate': 0.0002888398680617011, 'momentum': 0.6182601596762718}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# [I 2025-05-25 11:17:32,693] Trial 1 finished with value: 0.5841784989858012 and parameters: {'n_units1': 56, 'n_units2': 33, 'dropout_rate': 0.44938332090106003, 'learning_rate': 0.0010532450951107454, 'momentum': 0.27821100133657006}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [I 2025-05-25 11:17:35,614] Trial 2 finished with value: 0.5841784989858012 and parameters: {'n_units1': 84, 'n_units2': 36, 'dropout_rate': 0.2672645419722451, 'learning_rate': 0.02068312437493537, 'momentum': 0.46014090732908086}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [I 2025-05-25 11:17:47,891] Trial 3 finished with value: 0.5841784989858012 and parameters: {'n_units1': 68, 'n_units2': 29, 'dropout_rate': 0.16600093032014107, 'learning_rate': 0.00014084475976057536, 'momentum': 0.7785341721203958}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# [I 2025-05-25 11:17:51,649] Trial 4 finished with value: 0.5841784989858012 and parameters: {'n_units1': 79, 'n_units2': 20, 'dropout_rate': 0.4267059150719871, 'learning_rate': 0.009421305184274276, 'momentum': 0.021329779233201607}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# [I 2025-05-25 11:17:54,660] Trial 5 finished with value: 0.5841784989858012 and parameters: {'n_units1': 93, 'n_units2': 34, 'dropout_rate': 0.4633647821179354, 'learning_rate': 0.022888363329631293, 'momentum': 0.7101945364830397}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# [I 2025-05-25 11:18:03,993] Trial 6 finished with value: 0.5841784989858012 and parameters: {'n_units1': 57, 'n_units2': 35, 'dropout_rate': 0.4863556726473657, 'learning_rate': 0.00031789360832759465, 'momentum': 0.587420597150895}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# [I 2025-05-25 11:18:06,931] Trial 7 finished with value: 0.5841784989858012 and parameters: {'n_units1': 53, 'n_units2': 17, 'dropout_rate': 0.48673408064535395, 'learning_rate': 0.08652061827046519, 'momentum': 0.39067464505675326}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# [I 2025-05-25 11:18:23,679] Trial 8 finished with value: 0.5841784989858012 and parameters: {'n_units1': 55, 'n_units2': 47, 'dropout_rate': 0.16411215306844107, 'learning_rate': 0.00015472592724163198, 'momentum': 0.44545895696889004}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# [I 2025-05-25 11:18:26,847] Trial 9 finished with value: 0.5841784989858012 and parameters: {'n_units1': 81, 'n_units2': 35, 'dropout_rate': 0.40568189626006756, 'learning_rate': 0.07212747369803237, 'momentum': 0.6742993974880125}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# [I 2025-05-25 11:18:31,275] Trial 10 finished with value: 0.5841784989858012 and parameters: {'n_units1': 32, 'n_units2': 48, 'dropout_rate': 0.31579875838665106, 'learning_rate': 0.0013024846580632972, 'momentum': 0.8359484025128159}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# [I 2025-05-25 11:18:38,927] Trial 11 finished with value: 0.5841784989858012 and parameters: {'n_units1': 37, 'n_units2': 41, 'dropout_rate': 0.3377776424428076, 'learning_rate': 0.0011185145094539759, 'momentum': 0.19608111647078552}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [I 2025-05-25 11:18:54,132] Trial 12 finished with value: 0.5841784989858012 and parameters: {'n_units1': 44, 'n_units2': 28, 'dropout_rate': 0.38146947723960434, 'learning_rate': 0.0007338735337654603, 'momentum': 0.24078459141973663}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# [I 2025-05-25 11:18:58,740] Trial 13 finished with value: 0.5841784989858012 and parameters: {'n_units1': 67, 'n_units2': 42, 'dropout_rate': 0.25861447764488454, 'learning_rate': 0.003247471589853691, 'momentum': 0.2619787984776172}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# [I 2025-05-25 11:19:08,346] Trial 14 finished with value: 0.5841784989858012 and parameters: {'n_units1': 45, 'n_units2': 41, 'dropout_rate': 0.37728273388740874, 'learning_rate': 0.00044980182836321927, 'momentum': 0.5950745332218377}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# [I 2025-05-25 11:19:13,157] Trial 15 finished with value: 0.5841784989858012 and parameters: {'n_units1': 46, 'n_units2': 26, 'dropout_rate': 0.43629909619546414, 'learning_rate': 0.003539006290837653, 'momentum': 0.03595701797322459}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# [I 2025-05-25 11:19:18,921] Trial 16 finished with value: 0.5841784989858012 and parameters: {'n_units1': 63, 'n_units2': 44, 'dropout_rate': 0.35256779238231883, 'learning_rate': 0.00031505982766621293, 'momentum': 0.8909311294239676}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# [I 2025-05-25 11:19:25,110] Trial 17 finished with value: 0.5841784989858012 and parameters: {'n_units1': 72, 'n_units2': 24, 'dropout_rate': 0.23036863445868716, 'learning_rate': 0.0018768138803851348, 'momentum': 0.3652723970445061}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# [I 2025-05-25 11:19:32,985] Trial 18 finished with value: 0.5841784989858012 and parameters: {'n_units1': 51, 'n_units2': 38, 'dropout_rate': 0.4418360751174123, 'learning_rate': 0.0005758226907730358, 'momentum': 0.5453505876210577}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# [I 2025-05-25 11:19:50,416] Trial 19 finished with value: 0.5841784989858012 and parameters: {'n_units1': 61, 'n_units2': 30, 'dropout_rate': 0.10854052730780664, 'learning_rate': 0.00010817186121514414, 'momentum': 0.1418275014055383}. Best is trial 0 with value: 0.5841784989858012.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# [I 2025-05-25 11:20:01,747] A new study created in memory with name: no-name-8566bbe1-78e1-4d35-a8d5-3717fb869a1d
# Matriz de confusión:
# [[ 0 10]
#  [ 0 24]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [I 2025-05-25 11:20:04,586] Trial 0 finished with value: 0.728448275862069 and parameters: {'n_units1': 86, 'n_units2': 44, 'dropout_rate': 0.14466861730870742, 'learning_rate': 0.004774873771044541, 'momentum': 0.7758592603205221}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:20:07,728] Trial 1 finished with value: 0.5996963562753036 and parameters: {'n_units1': 81, 'n_units2': 23, 'dropout_rate': 0.33238688717700604, 'learning_rate': 0.003448513123733066, 'momentum': 0.28307404149059495}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# [I 2025-05-25 11:20:10,666] Trial 2 finished with value: 0.728448275862069 and parameters: {'n_units1': 69, 'n_units2': 30, 'dropout_rate': 0.14745214142470423, 'learning_rate': 0.038571014592457036, 'momentum': 0.7106903354992468}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# [I 2025-05-25 11:20:13,765] Trial 3 finished with value: 0.728448275862069 and parameters: {'n_units1': 43, 'n_units2': 37, 'dropout_rate': 0.47459148913664073, 'learning_rate': 0.003435168221236111, 'momentum': 0.3574755834473489}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# [I 2025-05-25 11:20:16,565] Trial 4 finished with value: 0.728448275862069 and parameters: {'n_units1': 41, 'n_units2': 24, 'dropout_rate': 0.18461405743874676, 'learning_rate': 0.00207677527491866, 'momentum': 0.6354290834844817}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# [I 2025-05-25 11:20:19,392] Trial 5 finished with value: 0.728448275862069 and parameters: {'n_units1': 39, 'n_units2': 42, 'dropout_rate': 0.25942439982948484, 'learning_rate': 0.0383701423777984, 'momentum': 0.6165505699332978}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# [I 2025-05-25 11:20:23,135] Trial 6 finished with value: 0.6964285714285714 and parameters: {'n_units1': 92, 'n_units2': 37, 'dropout_rate': 0.3875031627651596, 'learning_rate': 0.0020274528071304917, 'momentum': 0.5347889519798739}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:20:26,128] Trial 7 finished with value: 0.728448275862069 and parameters: {'n_units1': 63, 'n_units2': 29, 'dropout_rate': 0.17024477483861214, 'learning_rate': 0.009341835618719948, 'momentum': 0.2790981305815677}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:20:28,945] Trial 8 finished with value: 0.728448275862069 and parameters: {'n_units1': 88, 'n_units2': 22, 'dropout_rate': 0.1729363494183423, 'learning_rate': 0.005257181814099788, 'momentum': 0.5424187176733472}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# [I 2025-05-25 11:20:44,957] Trial 9 finished with value: 0.728448275862069 and parameters: {'n_units1': 50, 'n_units2': 28, 'dropout_rate': 0.4078531682903348, 'learning_rate': 0.00015154109657834308, 'momentum': 0.517478841216591}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:20:48,779] Trial 10 finished with value: 0.728448275862069 and parameters: {'n_units1': 73, 'n_units2': 48, 'dropout_rate': 0.10188065212778732, 'learning_rate': 0.0003445962097881484, 'momentum': 0.8527904919989185}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# [I 2025-05-25 11:20:52,104] Trial 11 finished with value: 0.728448275862069 and parameters: {'n_units1': 64, 'n_units2': 17, 'dropout_rate': 0.24886871040502614, 'learning_rate': 0.08602514795997393, 'momentum': 0.8611046348449123}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:20:54,980] Trial 12 finished with value: 0.728448275862069 and parameters: {'n_units1': 75, 'n_units2': 35, 'dropout_rate': 0.10298007047139347, 'learning_rate': 0.019546512491755038, 'momentum': 0.03638589761299138}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# [I 2025-05-25 11:20:57,996] Trial 13 finished with value: 0.05921052631578947 and parameters: {'n_units1': 58, 'n_units2': 46, 'dropout_rate': 0.218723224202905, 'learning_rate': 0.0009426185621996406, 'momentum': 0.7178481286571106}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# [I 2025-05-25 11:21:01,737] Trial 14 finished with value: 0.728448275862069 and parameters: {'n_units1': 96, 'n_units2': 42, 'dropout_rate': 0.3079915388743115, 'learning_rate': 0.01894667493691848, 'momentum': 0.7433732996433231}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:21:05,588] Trial 15 finished with value: 0.728448275862069 and parameters: {'n_units1': 82, 'n_units2': 32, 'dropout_rate': 0.14419406843498025, 'learning_rate': 0.0988058407211302, 'momentum': 0.7550810228270488}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:21:08,859] Trial 16 finished with value: 0.728448275862069 and parameters: {'n_units1': 71, 'n_units2': 42, 'dropout_rate': 0.22519531938835954, 'learning_rate': 0.0008198836820038662, 'momentum': 0.8834441296118392}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step
# [I 2025-05-25 11:21:11,907] Trial 17 finished with value: 0.728448275862069 and parameters: {'n_units1': 83, 'n_units2': 30, 'dropout_rate': 0.14220934039791833, 'learning_rate': 0.010759905619885792, 'momentum': 0.648598969154072}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# [I 2025-05-25 11:21:14,901] Trial 18 finished with value: 0.728448275862069 and parameters: {'n_units1': 51, 'n_units2': 35, 'dropout_rate': 0.2960273909863664, 'learning_rate': 0.04184530615240261, 'momentum': 0.42239121764453913}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:21:17,773] Trial 19 finished with value: 0.728448275862069 and parameters: {'n_units1': 32, 'n_units2': 16, 'dropout_rate': 0.20301496949026565, 'learning_rate': 0.03451489203643516, 'momentum': 0.03520453819846403}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:21:20,674] A new study created in memory with name: no-name-e80c884d-8c39-4d38-8288-789597005e36
# Matriz de confusión:
# [[ 0  3]
#  [ 0 13]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step
# [I 2025-05-25 11:21:27,516] Trial 0 finished with value: 1.0 and parameters: {'n_units1': 38, 'n_units2': 25, 'dropout_rate': 0.17682224028868254, 'learning_rate': 0.028648095387519862, 'momentum': 0.6571774547266054}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# [I 2025-05-25 11:21:30,762] Trial 1 finished with value: 1.0 and parameters: {'n_units1': 36, 'n_units2': 47, 'dropout_rate': 0.43439664795620425, 'learning_rate': 0.09201974506922804, 'momentum': 0.8327757812593853}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [I 2025-05-25 11:21:35,759] Trial 2 finished with value: 1.0 and parameters: {'n_units1': 77, 'n_units2': 44, 'dropout_rate': 0.2818035180514198, 'learning_rate': 0.0005036699204846659, 'momentum': 0.5880809604775519}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:21:38,670] Trial 3 finished with value: 1.0 and parameters: {'n_units1': 40, 'n_units2': 26, 'dropout_rate': 0.10138933090694265, 'learning_rate': 0.002479109713461179, 'momentum': 0.5543288023714584}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:21:42,443] Trial 4 finished with value: 1.0 and parameters: {'n_units1': 83, 'n_units2': 44, 'dropout_rate': 0.20294982181967366, 'learning_rate': 0.046918665294910074, 'momentum': 0.7853571576100609}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:21:47,168] Trial 5 finished with value: 0.6486486486486487 and parameters: {'n_units1': 46, 'n_units2': 25, 'dropout_rate': 0.15807827882710043, 'learning_rate': 0.0007791399554706772, 'momentum': 0.40801879089629833}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:22:02,501] Trial 6 finished with value: 1.0 and parameters: {'n_units1': 60, 'n_units2': 30, 'dropout_rate': 0.15505860078413736, 'learning_rate': 0.0001975482044265368, 'momentum': 0.3308868271708172}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:22:11,013] Trial 7 finished with value: 1.0 and parameters: {'n_units1': 76, 'n_units2': 20, 'dropout_rate': 0.4105251437873282, 'learning_rate': 0.00062652457387272, 'momentum': 0.19897165240065245}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:22:14,390] Trial 8 finished with value: 0.9795918367346939 and parameters: {'n_units1': 43, 'n_units2': 46, 'dropout_rate': 0.48761040802980016, 'learning_rate': 0.0009581993990088298, 'momentum': 0.7235529171689362}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:22:18,639] Trial 9 finished with value: 1.0 and parameters: {'n_units1': 74, 'n_units2': 29, 'dropout_rate': 0.33362253376960715, 'learning_rate': 0.0004944093416509682, 'momentum': 0.7677089019541973}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# [I 2025-05-25 11:22:21,672] Trial 10 finished with value: 1.0 and parameters: {'n_units1': 95, 'n_units2': 37, 'dropout_rate': 0.2601667175749972, 'learning_rate': 0.01583504814640645, 'momentum': 0.12955322458374452}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:22:25,390] Trial 11 finished with value: 1.0 and parameters: {'n_units1': 33, 'n_units2': 16, 'dropout_rate': 0.37209671984578424, 'learning_rate': 0.09469627022497891, 'momentum': 0.8828236910216563}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [I 2025-05-25 11:22:28,277] Trial 12 finished with value: 1.0 and parameters: {'n_units1': 55, 'n_units2': 37, 'dropout_rate': 0.49537439446946363, 'learning_rate': 0.015565023080197258, 'momentum': 0.5834667315373496}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# [I 2025-05-25 11:22:32,117] Trial 13 finished with value: 1.0 and parameters: {'n_units1': 34, 'n_units2': 36, 'dropout_rate': 0.42792731078396734, 'learning_rate': 0.017543473789502325, 'momentum': 0.8999271655842047}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# [I 2025-05-25 11:22:36,480] Trial 14 finished with value: 1.0 and parameters: {'n_units1': 51, 'n_units2': 24, 'dropout_rate': 0.2369268312160165, 'learning_rate': 0.09203125936889316, 'momentum': 0.6719119622435675}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [I 2025-05-25 11:22:40,528] Trial 15 finished with value: 1.0 and parameters: {'n_units1': 65, 'n_units2': 34, 'dropout_rate': 0.3297672317174406, 'learning_rate': 0.00586936851725081, 'momentum': 0.49163205920576486}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:22:43,461] Trial 16 finished with value: 1.0 and parameters: {'n_units1': 39, 'n_units2': 40, 'dropout_rate': 0.4275063962001434, 'learning_rate': 0.034892613793212464, 'momentum': 0.6643709751973995}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:22:46,338] Trial 17 finished with value: 1.0 and parameters: {'n_units1': 49, 'n_units2': 21, 'dropout_rate': 0.1874211056007993, 'learning_rate': 0.006196991792625704, 'momentum': 0.014229312445035114}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:22:49,692] Trial 18 finished with value: 1.0 and parameters: {'n_units1': 32, 'n_units2': 31, 'dropout_rate': 0.3261894764004434, 'learning_rate': 0.04077123030755371, 'momentum': 0.8439550210568176}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# [I 2025-05-25 11:22:52,864] Trial 19 finished with value: 1.0 and parameters: {'n_units1': 66, 'n_units2': 48, 'dropout_rate': 0.12801334046273388, 'learning_rate': 0.007889263526683982, 'momentum': 0.34541725336055973}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# [I 2025-05-25 11:22:56,242] A new study created in memory with name: no-name-9cbf4563-0372-4596-ba02-fc5d950d7b12
# Matriz de confusión:
# [[25]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [I 2025-05-25 11:23:00,227] Trial 0 finished with value: 0.728448275862069 and parameters: {'n_units1': 51, 'n_units2': 45, 'dropout_rate': 0.41120889857709, 'learning_rate': 0.0047274018441203144, 'momentum': 0.13604878804819678}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# [I 2025-05-25 11:23:05,328] Trial 1 finished with value: 0.728448275862069 and parameters: {'n_units1': 33, 'n_units2': 21, 'dropout_rate': 0.28562451554137547, 'learning_rate': 0.0014800601443701279, 'momentum': 0.4793621568826428}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step
# [I 2025-05-25 11:23:08,626] Trial 2 finished with value: 0.728448275862069 and parameters: {'n_units1': 39, 'n_units2': 39, 'dropout_rate': 0.46527125765354704, 'learning_rate': 0.005410045312097982, 'momentum': 0.2742880239869022}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step
# [I 2025-05-25 11:23:11,988] Trial 3 finished with value: 0.728448275862069 and parameters: {'n_units1': 59, 'n_units2': 30, 'dropout_rate': 0.4212211900245386, 'learning_rate': 0.006079059946732042, 'momentum': 0.03368843380555705}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# [I 2025-05-25 11:23:15,576] Trial 4 finished with value: 0.728448275862069 and parameters: {'n_units1': 75, 'n_units2': 27, 'dropout_rate': 0.11306234961028411, 'learning_rate': 0.011252037771229186, 'momentum': 0.39972819052180636}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# [I 2025-05-25 11:23:19,762] Trial 5 finished with value: 0.728448275862069 and parameters: {'n_units1': 67, 'n_units2': 29, 'dropout_rate': 0.2847041578137662, 'learning_rate': 0.0009377769296345263, 'momentum': 0.5630216673863796}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [I 2025-05-25 11:23:23,526] Trial 6 finished with value: 0.728448275862069 and parameters: {'n_units1': 72, 'n_units2': 47, 'dropout_rate': 0.42179959374689147, 'learning_rate': 0.08596108715502092, 'momentum': 0.42835371393520155}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:23:26,705] Trial 7 finished with value: 0.728448275862069 and parameters: {'n_units1': 85, 'n_units2': 48, 'dropout_rate': 0.210500738323551, 'learning_rate': 0.055676428710542125, 'momentum': 0.730016274860914}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:23:29,609] Trial 8 finished with value: 0.728448275862069 and parameters: {'n_units1': 60, 'n_units2': 45, 'dropout_rate': 0.1113438544416551, 'learning_rate': 0.014097902122225156, 'momentum': 0.6643222005035462}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# [I 2025-05-25 11:23:34,023] Trial 9 finished with value: 0.728448275862069 and parameters: {'n_units1': 50, 'n_units2': 46, 'dropout_rate': 0.39494449845624324, 'learning_rate': 0.0031690891340955545, 'momentum': 0.02595235066784032}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# [I 2025-05-25 11:23:51,596] Trial 10 finished with value: 0.728448275862069 and parameters: {'n_units1': 48, 'n_units2': 38, 'dropout_rate': 0.33558350845986806, 'learning_rate': 0.0001106002243430284, 'momentum': 0.21209061897368878}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# [I 2025-05-25 11:23:59,718] Trial 11 finished with value: 0.728448275862069 and parameters: {'n_units1': 32, 'n_units2': 22, 'dropout_rate': 0.27854473687721315, 'learning_rate': 0.0010017553031336592, 'momentum': 0.2309052064431426}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [I 2025-05-25 11:24:03,088] Trial 12 finished with value: 0.728448275862069 and parameters: {'n_units1': 46, 'n_units2': 20, 'dropout_rate': 0.3489159854339818, 'learning_rate': 0.0006922685992474851, 'momentum': 0.8563470275954397}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [I 2025-05-25 11:24:09,384] Trial 13 finished with value: 0.728448275862069 and parameters: {'n_units1': 34, 'n_units2': 35, 'dropout_rate': 0.21707932779735578, 'learning_rate': 0.000313616869636155, 'momentum': 0.5423336459974767}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:24:13,525] Trial 14 finished with value: 0.728448275862069 and parameters: {'n_units1': 94, 'n_units2': 24, 'dropout_rate': 0.47679024218410115, 'learning_rate': 0.001539032594188386, 'momentum': 0.34197500102644707}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# [I 2025-05-25 11:24:16,435] Trial 15 finished with value: 0.728448275862069 and parameters: {'n_units1': 42, 'n_units2': 16, 'dropout_rate': 0.2312870256291581, 'learning_rate': 0.027836785840465592, 'momentum': 0.17621995171971938}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# [I 2025-05-25 11:24:19,917] Trial 16 finished with value: 0.728448275862069 and parameters: {'n_units1': 53, 'n_units2': 40, 'dropout_rate': 0.3479578622142815, 'learning_rate': 0.002621048667251173, 'momentum': 0.504340203763776}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step
# [I 2025-05-25 11:24:36,747] Trial 17 finished with value: 0.728448275862069 and parameters: {'n_units1': 38, 'n_units2': 16, 'dropout_rate': 0.16352576312990388, 'learning_rate': 0.000410949331848188, 'momentum': 0.102347637629304}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step
# [I 2025-05-25 11:24:40,856] Trial 18 finished with value: 0.728448275862069 and parameters: {'n_units1': 56, 'n_units2': 34, 'dropout_rate': 0.38040527727211315, 'learning_rate': 0.002550441362601742, 'momentum': 0.3286177701326566}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# [I 2025-05-25 11:24:50,544] Trial 19 finished with value: 0.728448275862069 and parameters: {'n_units1': 44, 'n_units2': 26, 'dropout_rate': 0.2551310126850159, 'learning_rate': 0.00014974707951717763, 'momentum': 0.661660034616374}. Best is trial 0 with value: 0.728448275862069.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:24:53,889] A new study created in memory with name: no-name-28802386-439c-403a-acc3-8a7c1c2e289d
# Matriz de confusión:
# [[ 0  3]
#  [ 0 13]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step
# [I 2025-05-25 11:25:04,178] Trial 0 finished with value: 0.8768115942028986 and parameters: {'n_units1': 48, 'n_units2': 28, 'dropout_rate': 0.1064919437234992, 'learning_rate': 0.001954579170975967, 'momentum': 0.3554307795721609}. Best is trial 0 with value: 0.8768115942028986.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# [I 2025-05-25 11:25:16,546] Trial 1 finished with value: 0.8768115942028986 and parameters: {'n_units1': 74, 'n_units2': 43, 'dropout_rate': 0.3022418991808598, 'learning_rate': 0.0020598418871962186, 'momentum': 0.23008194982049138}. Best is trial 0 with value: 0.8768115942028986.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# [I 2025-05-25 11:25:21,778] Trial 2 finished with value: 0.8768115942028986 and parameters: {'n_units1': 73, 'n_units2': 21, 'dropout_rate': 0.3709306967269618, 'learning_rate': 0.019233634199064636, 'momentum': 0.08271025865629857}. Best is trial 0 with value: 0.8768115942028986.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# [I 2025-05-25 11:25:27,984] Trial 3 finished with value: 0.8768115942028986 and parameters: {'n_units1': 82, 'n_units2': 48, 'dropout_rate': 0.2460725494920923, 'learning_rate': 0.005488587990560923, 'momentum': 0.396942253792335}. Best is trial 0 with value: 0.8768115942028986.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# ...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# [I 2025-05-25 17:07:10,981] Trial 16 finished with value: 0.5952380952380952 and parameters: {'n_units1': 55, 'n_units2': 20, 'dropout_rate': 0.20583470348480748, 'learning_rate': 0.003389751241696555, 'momentum': 0.00807606178765774}. Best is trial 0 with value: 0.5952380952380952.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:07:12,587] Trial 17 finished with value: 0.5952380952380952 and parameters: {'n_units1': 72, 'n_units2': 28, 'dropout_rate': 0.307317071718875, 'learning_rate': 0.026886075230209066, 'momentum': 0.6886437732405714}. Best is trial 0 with value: 0.5952380952380952.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:07:19,515] Trial 18 finished with value: 0.5952380952380952 and parameters: {'n_units1': 40, 'n_units2': 48, 'dropout_rate': 0.4450101178669856, 'learning_rate': 0.0009577982744695018, 'momentum': 0.48581557470804587}. Best is trial 0 with value: 0.5952380952380952.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:07:21,771] Trial 19 finished with value: 0.5952380952380952 and parameters: {'n_units1': 47, 'n_units2': 21, 'dropout_rate': 0.36826860789320165, 'learning_rate': 0.005704617983896626, 'momentum': 0.5762553640840743}. Best is trial 0 with value: 0.5952380952380952.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# [I 2025-05-25 17:07:30,726] A new study created in memory with name: no-name-25fb5655-8270-4554-8966-0a26b479cad8
# Matriz de confusión:
# [[ 0  4]
#  [ 0 10]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:07:32,294] Trial 0 finished with value: 0.9256410256410256 and parameters: {'n_units1': 94, 'n_units2': 19, 'dropout_rate': 0.3662576501573426, 'learning_rate': 0.049614493561308017, 'momentum': 0.5031127619239628}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:07:34,094] Trial 1 finished with value: 0.9256410256410256 and parameters: {'n_units1': 91, 'n_units2': 43, 'dropout_rate': 0.38712671324584347, 'learning_rate': 0.0030547113008950032, 'momentum': 0.5763312467344214}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [I 2025-05-25 17:07:36,882] Trial 2 finished with value: 0.9256410256410256 and parameters: {'n_units1': 48, 'n_units2': 27, 'dropout_rate': 0.2980825659663116, 'learning_rate': 0.004347507554282938, 'momentum': 0.055635980200931794}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:07:43,204] Trial 3 finished with value: 0.9256410256410256 and parameters: {'n_units1': 57, 'n_units2': 22, 'dropout_rate': 0.29352029556165404, 'learning_rate': 0.00015833855427053954, 'momentum': 0.838784598288948}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:07:45,787] Trial 4 finished with value: 0.9256410256410256 and parameters: {'n_units1': 41, 'n_units2': 29, 'dropout_rate': 0.28662936816835016, 'learning_rate': 0.0013265411930667296, 'momentum': 0.6155330063088669}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:07:47,697] Trial 5 finished with value: 0.9256410256410256 and parameters: {'n_units1': 49, 'n_units2': 48, 'dropout_rate': 0.10809479510000371, 'learning_rate': 0.004593566550272052, 'momentum': 0.5871875387322794}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:07:49,876] Trial 6 finished with value: 0.9256410256410256 and parameters: {'n_units1': 83, 'n_units2': 33, 'dropout_rate': 0.12353601286525234, 'learning_rate': 0.001591515501645064, 'momentum': 0.584015585004423}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:07:54,552] Trial 7 finished with value: 0.9256410256410256 and parameters: {'n_units1': 78, 'n_units2': 43, 'dropout_rate': 0.48039375548722774, 'learning_rate': 0.00040158073706338896, 'momentum': 0.511131020763337}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:07:56,101] Trial 8 finished with value: 0.9256410256410256 and parameters: {'n_units1': 44, 'n_units2': 26, 'dropout_rate': 0.21018150976500807, 'learning_rate': 0.031033833062534284, 'momentum': 0.518504942820225}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:07:57,756] Trial 9 finished with value: 0.9256410256410256 and parameters: {'n_units1': 46, 'n_units2': 35, 'dropout_rate': 0.3790162896828754, 'learning_rate': 0.010646002918645448, 'momentum': 0.4408404632004372}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [I 2025-05-25 17:07:59,360] Trial 10 finished with value: 0.9256410256410256 and parameters: {'n_units1': 70, 'n_units2': 18, 'dropout_rate': 0.4890640362083908, 'learning_rate': 0.07808882600262164, 'momentum': 0.26828429945783033}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:08:00,929] Trial 11 finished with value: 0.9256410256410256 and parameters: {'n_units1': 93, 'n_units2': 39, 'dropout_rate': 0.3960624495231205, 'learning_rate': 0.015299825969318243, 'momentum': 0.7429171372688392}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:08:02,491] Trial 12 finished with value: 0.9256410256410256 and parameters: {'n_units1': 96, 'n_units2': 16, 'dropout_rate': 0.4064697282259263, 'learning_rate': 0.09483354545176388, 'momentum': 0.3350719029205691}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:08:05,827] Trial 13 finished with value: 0.9256410256410256 and parameters: {'n_units1': 86, 'n_units2': 48, 'dropout_rate': 0.3520274140220497, 'learning_rate': 0.0007581253789950194, 'momentum': 0.7245898546557773}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:08:07,655] Trial 14 finished with value: 0.9256410256410256 and parameters: {'n_units1': 32, 'n_units2': 42, 'dropout_rate': 0.4378715400852452, 'learning_rate': 0.01159334758512857, 'momentum': 0.35286826573471075}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:08:09,232] Trial 15 finished with value: 0.9256410256410256 and parameters: {'n_units1': 71, 'n_units2': 23, 'dropout_rate': 0.34663621539119993, 'learning_rate': 0.03165483292419474, 'momentum': 0.19642694750080714}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:08:11,174] Trial 16 finished with value: 0.9256410256410256 and parameters: {'n_units1': 88, 'n_units2': 38, 'dropout_rate': 0.2556018821060955, 'learning_rate': 0.0025580708754053584, 'momentum': 0.6847971027984503}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:08:12,742] Trial 17 finished with value: 0.9256410256410256 and parameters: {'n_units1': 75, 'n_units2': 30, 'dropout_rate': 0.2225900793723363, 'learning_rate': 0.005963377971461397, 'momentum': 0.8991089982605591}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# [I 2025-05-25 17:08:14,315] Trial 18 finished with value: 0.9256410256410256 and parameters: {'n_units1': 62, 'n_units2': 21, 'dropout_rate': 0.44333106291342705, 'learning_rate': 0.04090757906117389, 'momentum': 0.45250032933900924}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# [I 2025-05-25 17:08:21,214] Trial 19 finished with value: 0.9256410256410256 and parameters: {'n_units1': 91, 'n_units2': 44, 'dropout_rate': 0.3398943047923955, 'learning_rate': 0.00035969558342751967, 'momentum': 0.429890574785123}. Best is trial 0 with value: 0.9256410256410256.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:08:22,956] A new study created in memory with name: no-name-fcca48ad-ddfc-4a39-b9ea-7af417a3d150
# Matriz de confusión:
# [[ 0  1]
#  [ 0 19]]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [I 2025-05-25 17:08:24,547] Trial 0 finished with value: 1.0 and parameters: {'n_units1': 48, 'n_units2': 32, 'dropout_rate': 0.47675558123033346, 'learning_rate': 0.07613382159957505, 'momentum': 0.17638964133877538}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [I 2025-05-25 17:08:32,411] Trial 1 finished with value: 1.0 and parameters: {'n_units1': 32, 'n_units2': 26, 'dropout_rate': 0.40009264741998685, 'learning_rate': 0.0002388771737164267, 'momentum': 0.47318580645792474}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:08:33,908] Trial 2 finished with value: 1.0 and parameters: {'n_units1': 95, 'n_units2': 33, 'dropout_rate': 0.2216422043648656, 'learning_rate': 0.02776257301817534, 'momentum': 0.06719369062273026}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# [I 2025-05-25 17:08:35,657] Trial 3 finished with value: 1.0 and parameters: {'n_units1': 49, 'n_units2': 45, 'dropout_rate': 0.3207292786309427, 'learning_rate': 0.0029348308678291924, 'momentum': 0.793136945136256}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:08:37,162] Trial 4 finished with value: 1.0 and parameters: {'n_units1': 93, 'n_units2': 29, 'dropout_rate': 0.2033867832790182, 'learning_rate': 0.017456581495094683, 'momentum': 0.4354480816917201}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# [I 2025-05-25 17:08:40,341] Trial 5 finished with value: 1.0 and parameters: {'n_units1': 63, 'n_units2': 24, 'dropout_rate': 0.42791526440868866, 'learning_rate': 0.0011582818942023603, 'momentum': 0.05877485517692972}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:08:41,843] Trial 6 finished with value: 1.0 and parameters: {'n_units1': 96, 'n_units2': 32, 'dropout_rate': 0.3984374519541338, 'learning_rate': 0.04047092522374193, 'momentum': 0.26832341652231817}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:08:43,676] Trial 7 finished with value: 1.0 and parameters: {'n_units1': 84, 'n_units2': 45, 'dropout_rate': 0.335081367356196, 'learning_rate': 0.006706931936726849, 'momentum': 0.18026402817861203}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [I 2025-05-25 17:08:45,271] Trial 8 finished with value: 1.0 and parameters: {'n_units1': 34, 'n_units2': 42, 'dropout_rate': 0.20197885956569236, 'learning_rate': 0.0031480155322460386, 'momentum': 0.8858892655894841}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [I 2025-05-25 17:08:54,237] Trial 9 finished with value: 1.0 and parameters: {'n_units1': 40, 'n_units2': 16, 'dropout_rate': 0.11771888908834015, 'learning_rate': 0.0004868842020868993, 'momentum': 0.23571675822539953}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# [I 2025-05-25 17:08:55,744] Trial 10 finished with value: 1.0 and parameters: {'n_units1': 59, 'n_units2': 38, 'dropout_rate': 0.4907209642384336, 'learning_rate': 0.07355807301061015, 'momentum': 0.4772789535450615}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [I 2025-05-25 17:09:04,798] Trial 11 finished with value: 1.0 and parameters: {'n_units1': 47, 'n_units2': 23, 'dropout_rate': 0.49645624200637856, 'learning_rate': 0.00011470160072836016, 'momentum': 0.5287889993435718}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# [I 2025-05-25 17:09:13,778] Trial 12 finished with value: 1.0 and parameters: {'n_units1': 33, 'n_units2': 24, 'dropout_rate': 0.4160365918490489, 'learning_rate': 0.00010541655977318399, 'momentum': 0.6589923409361688}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# [I 2025-05-25 17:09:22,591] Trial 13 finished with value: 1.0 and parameters: {'n_units1': 50, 'n_units2': 37, 'dropout_rate': 0.37369100265597666, 'learning_rate': 0.00046382409566469014, 'momentum': 0.3587205354614204}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# [I 2025-05-25 17:09:24,194] Trial 14 finished with value: 1.0 and parameters: {'n_units1': 41, 'n_units2': 28, 'dropout_rate': 0.45068043225242616, 'learning_rate': 0.00941191795503657, 'momentum': 0.6120074611125864}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# [I 2025-05-25 17:09:32,680] Trial 15 finished with value: 1.0 and parameters: {'n_units1': 71, 'n_units2': 18, 'dropout_rate': 0.3628650254589614, 'learning_rate': 0.0003154632225945058, 'momentum': 0.3370466412544023}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# [I 2025-05-25 17:09:34,197] Trial 16 finished with value: 1.0 and parameters: {'n_units1': 56, 'n_units2': 35, 'dropout_rate': 0.25468603570190507, 'learning_rate': 0.09325815421094485, 'momentum': 0.1447039448460944}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# [I 2025-05-25 17:09:36,879] Trial 17 finished with value: 1.0 and parameters: {'n_units1': 73, 'n_units2': 28, 'dropout_rate': 0.28064566880566333, 'learning_rate': 0.001238946731905225, 'momentum': 0.6198565797334148}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [I 2025-05-25 17:09:41,571] Trial 18 finished with value: 1.0 and parameters: {'n_units1': 41, 'n_units2': 20, 'dropout_rate': 0.4463975480383802, 'learning_rate': 0.001424233050717608, 'momentum': 0.37070187725813714}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# [I 2025-05-25 17:09:43,182] Trial 19 finished with value: 1.0 and parameters: {'n_units1': 54, 'n_units2': 31, 'dropout_rate': 0.45587416843524864, 'learning_rate': 0.00966825247972296, 'momentum': 0.7115829866101798}. Best is trial 0 with value: 1.0.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ERROR:tornado.application:Exception in callback functools.partial(<bound method OutStream._flush of <ipykernel.iostream.OutStream object at 0x0000026C82DAB730>>)
# Traceback (most recent call last):
#   File "c:\Users\sebas\OneDrive\Escritorio\TFM-Ciencia de datos\venv\Lib\site-packages\jupyter_client\session.py", line 100, in json_packer
#     ).encode("utf8", errors="surrogateescape")
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 138-139: surrogates not allowed
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\sebas\OneDrive\Escritorio\TFM-Ciencia de datos\venv\Lib\site-packages\tornado\ioloop.py", line 758, in _run_callback
#     ret = callback()
#           ^^^^^^^^^^
#   File "c:\Users\sebas\OneDrive\Escritorio\TFM-Ciencia de datos\venv\Lib\site-packages\ipykernel\iostream.py", line 649, in _flush
#     self.session.send(
#   File "c:\Users\sebas\OneDrive\Escritorio\TFM-Ciencia de datos\venv\Lib\site-packages\jupyter_client\session.py", line 852, in send
#     to_send = self.serialize(msg, ident)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sebas\OneDrive\Escritorio\TFM-Ciencia de datos\venv\Lib\site-packages\jupyter_client\session.py", line 721, in serialize
#     content = self.pack(content)
#               ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\sebas\OneDrive\Escritorio\TFM-Ciencia de datos\venv\Lib\site-packages\jupyter_client\session.py", line 108, in json_packer
#     ).encode("utf8", errors="surrogateescape")
#       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeEncodeError: 'utf-8' codec can't encode characters in position 138-139: surrogates not allowed

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# Cargar archivo de resultados generado por el script
results_path = os.path.join(os.getcwd(), "results_walkforward_weekly_keras_optuna.csv")

# Cargar en DataFrame
df_results = pd.read_csv(results_path)

# Visualización extendida en otra fila: mostrar métricas y dropout por fold
fig, axs = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

# F1 Score
axs[0].plot(df_results["F1_Score"], marker='o', label='F1 Score')
axs[0].axhline(df_results["F1_Score"].mean(), color='red', linestyle='--', label='Promedio F1')
axs[0].set_ylabel('F1 Score')
axs[0].legend()
axs[0].grid(True)

# Dropout
axs[1].plot(df_results["Dropout"], marker='s', color='purple', label='Dropout Rate')
axs[1].axhline(df_results["Dropout"].mean(), color='gray', linestyle='--', label='Promedio Dropout')
axs[1].set_xlabel('Fold')
axs[1].set_ylabel('Dropout Rate')
axs[1].legend()
axs[1].grid(True)

plt.suptitle('Evolución de F1 Score y Dropout Rate por Fold')
plt.tight_layout()
plt.show()
